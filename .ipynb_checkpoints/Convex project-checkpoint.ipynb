# %% [markdown]
# This notebook produces solves the problem discussed in this repository: the revisited diet problem. It uses mainly cvxopt librairy to solve the problem for a given set of dishes.
# **First** we make the statement of the problem, **then** we look at the solution and **finally** do some sensitivity analysis.
# Do not hesitate to take a look to the report for more information.

# %% [markdown]
# # Revisited Diet problem:

# %%
# import librairies
from math import sqrt
from cvxopt.blas import dot
from cvxopt.solvers import options
import pylab
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from cvxopt import matrix, solvers

# put true to see detailled iterations
options['show_progress'] = False

VERBOSE = False

# %% [markdown]
# ### 1. Statement of the problem:

# %%
# State the problem: construct the matrices to feed to the solver. Look at the report for more details


# tastes vector
t = np.array([4.9   ,    3.9   ,   4.4   , 4    ,   4.4]).reshape(-1,1)
t=matrix(t)

# cost ector
c = np.array([5.5   ,    4.5    ,   5   ,  3.5    ,  3.4]).reshape(-1,1)
c= matrix(c)

# nutriment matrix
A = np.array(
    [
        [c[0]  ,  199     , 11.37 ,  6.71         , 16.72],
        [c[1]  ,  191     , 13    ,  5.2          , 13 ],
        [c[2] ,  128     , 5.5   ,  5.5          , 14  ],
        [c[3] ,  191     , 7.43  ,  17.36        , 12.58],
        [c[4] ,  116     , 1.88  ,  21.04        , 4.14  ]
    ]).transpose()

# lower and upper bounds

b_2 = np.array([14.0  , 450.0     , 30.0 ,  50.0    , 60.0 ])
b_1 = np.array([0.0  ,0.0    , 0.0 ,  0.0    , 30.0])

food_min=np.array([0.8])
food_max=np.array([3.])

# vector of ones and identity matrix
ones = np.ones(A.shape[0]).reshape(1,-1)
I = np.eye(A.shape[0])
O = np.zeros(I.shape[0])

#creation of A_tilde, b_tilde
A_tilde = np.concatenate((A,-A,ones, -ones,-I),axis=0)
A_tilde = matrix(A_tilde)

b_tilde = np.concatenate((b_2,-b_1,food_max,-food_min,O)).reshape(-1,1)
b_tilde = matrix(b_tilde)

# the final objective function
def Cost(gamma=1):
    return (-t + gamma * c)

# %% [markdown]
# ### 2. Solve the problem and look at solutions:

# %%
# define the trade-off parameter gamma and solve the problem
N = 100
gammas = [ 1.5*t/N for t in range(N) ]

xs = [ solvers.lp(Cost(gamma),A_tilde,b_tilde)['x'] for gamma in gammas ]

# %%
# plot results 


cost = [ dot(c,x) for x in xs ]
taste = [ dot(t, x) for x in xs ]

p1 = plt.figure(1)#, figsize=(10,8))
plt.plot(taste,cost,'--r', label='minimal curve')
plt.xlabel('taste')
plt.ylabel('cost')
plt.grid()
plt.title('Pareto-optimal curve between taste and cost')
plt.text(11.5,9,'infeasible region')
plt.text(10,12,'non pareto-optimal region')
plt.xlim(np.min(taste),np.max(taste))
plt.ylim(np.min(cost),np.max(cost))

#plt.legend(['pareto-optimal front'],loc='upper left')
x = [np.min(taste), 12.75 , np.max(taste),np.min(taste)]
y = [np.min(cost), 11.5 , np.max(cost),np.max(cost)]
plt.fill(x, y,\
         color='b',alpha=0.5)
plt.legend(loc='upper left')
p1.savefig('trade-off.png')
plt.show()

# %%
# useless figure trying to imitate the beautiful one of Boyd

pylab.figure(2)
c1 = [ x[0] for x in xs ]
c2 = [ x[0] + x[1] for x in xs ]
c3 = [ x[0] + x[1] + x[2] for x in xs ]
c4 = [ x[0] + x[1] + x[2] + x[3] for x in xs ]
c5 = [ x[0] + x[1] + x[2] + x[3] + x[4] for x in xs ]
risks = taste
pylab.fill(risks + [.20], c1 + [0.0], facecolor = 'r')
pylab.fill(risks[-1::-1] + risks, c2[-1::-1] + c1,
    facecolor = 'g')
pylab.fill(risks[-1::-1] + risks, c3[-1::-1] + c2,
    facecolor = 'y')
pylab.fill(risks[-1::-1] + risks, c4[-1::-1] + c3,
    facecolor = 'b')
pylab.fill(risks[-1::-1] + risks, c5[-1::-1] + c4,
    facecolor = 'm')
#pylab.axis([0.0, 0.2, 0.0, 1.0])
pylab.xlabel('taste')
pylab.ylabel('cost')
"""pylab.text(.15,.5,'x1')
pylab.text(.10,.7,'x2')
pylab.text(.05,.7,'x3')
pylab.text(.01,.7,'x4')"""
pylab.title('Optimal allocations (fig 4.12)')
pylab.show()

# %%
# plot distribution of dishes of the pareto-optimal solution

t1 = [  x[0] for x in xs ]
t2 = [  x[1] for x in xs ]
t3 = [  x[2] for x in xs ]
t4 = [  x[3] for x in xs ]
t5 = [  x[4] for x in xs ]


foods = [t1,t2,t3,t4,t5]
foods_label = ['Fried Fish','meatballs','octopus salad','Meat Ravioli','Tomato Pasta']
p2 = plt.figure(2,figsize=(8,5))
for i in range(0,len(foods)):
    #plt.fill_between(x_, 0, x)
    plt.plot(gammas,np.dot(100,foods[i]),label=foods_label[i])
plt.xlabel('gamma')
plt.ylabel('gramms of each food')
plt.xlim(0,1.5)
plt.ylim(0,300)
plt.legend(loc='best')

plt.show()
p2.savefig('gramms_of_food.png')

# %% [markdown]
# ### 3. Analysis of the other parameters:

# %%
sols = [ solvers.lp(Cost(gamma),A_tilde,b_tilde) for gamma in gammas ];

# %%
# example
gamma = 1.3
solvers.lp(Cost(gamma),A_tilde,b_tilde)
# Out:
# {'dual infeasibility': 9.265305480418658e-11,
#  'dual objective': 1.4081182991023493,
#  'dual slack': 2.0250892980238225e-11,
#  'gap': 8.508641622516474e-08,
#  'iterations': 9,
#  'primal infeasibility': 2.876902467356228e-12,
#  'primal objective': 1.4081183828888435,
#  'primal slack': 1.7963812122938777e-09,
#  'relative gap': 6.04256164268342e-08,
#  'residual as dual infeasibility certificate': None,
#  'residual as primal infeasibility certificate': None,
#  's': <17x1 matrix, tc='d'>,
#  'status': 'optimal',
#  'x': <5x1 matrix, tc='d'>,
#  'y': <0x1 matrix, tc='d'>,
#  'z': <17x1 matrix, tc='d'>}

# %%
# check the primal and dual coincide:

prim_obj = [ sol['primal objective'] for sol in sols ]
dual_obj = [ sol['dual objective'] for sol in sols ]
p3 = plt.figure(3)
plt.plot(gammas, prim_obj,'--b',label='primal objective')
plt.plot(gammas, dual_obj,'-r',alpha=0.6, label = 'dual objective')
plt.legend(loc='best')
plt.show()

# %%
prim_slack = [ sol['primal slack'] for sol in sols ]
dual_slack = [ sol['dual slack'] for sol in sols ]
p4 = plt.figure(4)
plt.plot(gammas,prim_slack,'--b',label='primal slack')
plt.plot(gammas,dual_slack,'-r',alpha=0.6, label = 'dual slack')
plt.legend(loc='best')
plt.show()

# %%
lambdas = np.array([ np.array(sol['z']) for sol in sols])

maxes, argmaxes = np.max(np.abs(lambdas),axis=1), np.argmax(np.abs(lambdas),axis=1)
plt.plot(gammas,argmaxes,'.')
index_of_transition = np.where(argmaxes==np.max(argmaxes))[0][0]
value_of_transition = gammas[index_of_transition]
print(value_of_transition)
plt.show()
# Out:
# 0.87

# %%
print (len(gammas[:index_of_transition]))
lambdas[:index_of_transition,10].reshape(-1).shape
# Out:
# 58
# (58,)

# %%
# plot greatest dual variables
p6 = plt.figure(6, figsize=(10,8))
plt.plot(gammas[:index_of_transition],lambdas[:index_of_transition,10].reshape(-1),\
         '--r',label='la')
plt.plot(gammas[index_of_transition:],lambdas[index_of_transition:,13].reshape(-1),\
         '--b',label='la')
#plt.plot(gammas[index_of_transition:],maxes[index_of_transition:],'.')
plt.xlabel('gammas')
plt.ylabel('value of dual variable')
plt.grid()
plt.title('Sensitivity analysis: greatest dual variable ')
#plt.text(11.5,9,'infeasible region')
#plt.text(10,12,'non pareto-optimal region')
#plt.xlim(np.min(taste),np.max(taste))
#plt.ylim(np.min(cost),np.max(cost))

"""#plt.legend(['pareto-optimal front'],loc='upper left')
x = [np.min(taste), 12.75 , np.max(taste),np.min(taste)]
y = [np.min(cost), 11.5 , np.max(cost),np.max(cost)]
plt.fill(x, y,\
         color='b',alpha=0.5)"""
plt.legend(loc='best')
#p1.savefig('trade-off.png')
plt.show()

# %%
# dual variables: 

p7 = plt.figure(7, figsize=(8,6))
lambda_list = [9,10,12,13,15]
for i in lambda_list:
    plt.plot(gammas,lambdas[:,i].reshape(-1), label = 'lambda '+str(i+1))
plt.legend(loc='best')

#plt.plot(gammas[index_of_transition:],maxes[index_of_transition:],'.')
plt.xlabel('gamma')
plt.ylabel('value of dual variables')
plt.grid()
plt.title('Sensitivity analysis: dual variables ')
#plt.text(11.5,9,'infeasible region')
#plt.text(10,12,'non pareto-optimal region')
#plt.xlim(np.min(taste),np.max(taste))
#plt.ylim(np.min(cost),np.max(cost))

plt.legend(loc='best')
p7.savefig('dual_variables.png')
plt.show()
